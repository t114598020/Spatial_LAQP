# %% [markdown]
# ### Step1: Load POWER dataset

# %%
import pandas as pd
import numpy as np

# Path to power txt file
file_path = './data/household_power_consumption.txt'
# Load with ; separator, handle '?' as NaN
data = pd.read_csv(file_path, sep=';', na_values='?')

# Combine Date and Time to datetime
data['datetime'] = pd.to_datetime(data['Date'] + ' ' + data['Time'], format='%d/%m/%Y %H:%M:%S')
# Numerical timestamp: seconds since the earliest date
min_dt = data['datetime'].min()
data['timestamp'] = (data['datetime'] - min_dt).dt.total_seconds()

# Relevant columns (drop Date/Time/datetime, keep numerics)
cols = ['timestamp', 'Global_active_power', 'Global_reactive_power', 'Voltage', 
        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']
data = data[cols].dropna()  # ~1.25% missing, drop for simplicity
full_data_size = len(data)
# Define dimensions (7D) and their min/max
dimensions = ['timestamp', 'Global_reactive_power', 'Voltage', 'Global_intensity', 
              'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']
agg_col = 'Global_active_power'

print(f"Dataset loaded: {full_data_size} rows")
print(f"First 5 data: {data.head()}")
# Out:
# Dataset loaded: 2049280 rows
# First 5 data:    timestamp  Global_active_power  Global_reactive_power  Voltage  \
# 0        0.0                4.216                  0.418   234.84
# 1       60.0                5.360                  0.436   233.63
# 2      120.0                5.374                  0.498   233.29
# 3      180.0                5.388                  0.502   233.74
# 4      240.0                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %% [markdown]
# ### Step2: Create a Small Offline Sample

# %%
sample_size = 2000
sample = data.sample(n=sample_size, random_state=42).copy()
print(f"Sample created: {sample.shape[0]} rows")
print(sample.head())
# Out:
# Sample created: 2000 rows
#           timestamp  Global_active_power  Global_reactive_power  Voltage  \
# 1030580  61834800.0                1.502                  0.074   240.17
# 1815       108900.0                0.374                  0.264   245.50
# 1295977  77758620.0                0.620                  0.300   239.85
# 206669   12400140.0                0.280                  0.200   235.72
# 1048893  62933580.0                1.372                  0.054   243.95
#
#          Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 1030580               6.4             0.0             0.0            18.0
# 1815                  1.8             0.0             2.0             0.0
# 1295977               3.0             0.0             1.0             1.0
# 206669                1.4             0.0             0.0             0.0
# 1048893               5.6             0.0             0.0            18.0

# %% [markdown]
# ### Step 3: Generate Query Log, training data, testing data, optimize testing data.
#
# Chapter 6.1: "In order to avoid most of the multi-dimensional query results to be zero, we limit the range to generate the boundaries in each dimension. The left boundary of the range in each dimension is randomly chosen from the first quarter of the entire value range of the corresponding attribute. Similarly, each right boundary is randomly chosen from the last quarter of the corresponding attribute range."

# %%
from query_generate import generate_bounded_random_query

# generate a random query to test and see min, max value.
q = generate_bounded_random_query(data, dimensions, test = True)
print(q)
# Out:
# dim: timestamp, min value: 0.0, max value: 124515480.0
# dim: Global_reactive_power, min value: 0.0, max value: 1.39
# dim: Voltage, min value: 223.2, max value: 254.15
# dim: Global_intensity, min value: 0.2, max value: 48.4
# dim: Sub_metering_1, min value: 0.0, max value: 88.0
# dim: Sub_metering_2, min value: 0.0, max value: 80.0
# dim: Sub_metering_3, min value: 0.0, max value: 31.0
# {'timestamp': (7566732.343445038, 101684946.29980099), 'Global_reactive_power': (0.15440463061607754, 1.2647993516069838), 'Voltage': (225.2195313677604, 250.05620493609038), 'Global_intensity': (11.05432931048991, 40.07293151263805), 'Sub_metering_1': (18.62337498080614, 67.41113009875228), 'Sub_metering_2': (12.120008622526402, 78.42069341300271), 'Sub_metering_3': (6.706861117506489, 26.563710961889182)}

# %% [markdown]
# Build query log (around 20 mins), the main task is SUM.

# %%
from query_generate import generate_power_query_log

task = "SUM"
# number of queries
num_queries = 2000

avg_exact, query_log = generate_power_query_log(agg_col, num_queries, data, sample, dimensions, full_data_size, avg_exact=0)

query_log = generate_power_query_log(agg_col, num_queries, data, sample, dimensions, full_data_size, avg_exact=avg_exact)
# Out:
# Generating power query log...
# Average exact sum: avg_exact=14070.983594
# Generated 2000 queries in 3947 attempts
#
# Generating power query log...
# Generated 2000 queries in 4006 attempts

# %%
# Check any query in query log.
query_log[100]
# Out:
# {'query': {'timestamp': (25047314.27334792, 111465651.94807582),
#   'Global_reactive_power': (0.15262524265853103, 1.242600660064423),
#   'Voltage': (230.23119108362093, 250.0558855447157),
#   'Global_intensity': (3.540095889425396, 42.90043665438955),
#   'Sub_metering_1': (13.76045969017667, 83.94763831194655),
#   'Sub_metering_2': (13.887084192864826, 61.581055645424144),
#   'Sub_metering_3': (0.06726697100681947, 24.40210741795285)},
#  'exact': 7867.976,
#  'estimate': 4834.251520000001,
#  'error': 3033.724479999999}

# %% [markdown]
# Build training data with diversification.

# %%
from diversification import diversify_query_log

training_data_query_log = diversify_query_log(query_log, dimensions, k=800)
# Out:
# Diversified query log: selected 800 / 2000 entries

# %%
# CHeck any query in diversify query log.
training_data_query_log[100]
# Out:
# {'query': {'timestamp': (2522916.8224836104, 121163414.04347233),
#   'Global_reactive_power': (0.27300236714281256, 1.374143970932587),
#   'Voltage': (226.93596117559355, 247.92612645575355),
#   'Global_intensity': (2.732313215056441, 43.314014118306694),
#   'Sub_metering_1': (8.461043494466665, 68.97294274695196),
#   'Sub_metering_2': (0.9884716135547089, 75.28694080735397),
#   'Sub_metering_3': (6.999956320337804, 30.228870581805467)},
#  'exact': 29737.794,
#  'estimate': 36803.01952,
#  'error': -7065.22552}

# %% [markdown]
# Graph of before diversification and after.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from visualization import extract_features

pca_scaler = StandardScaler()

# Extract features for original and diversified
original_features = extract_features(query_log, dimensions)
diversified_features = extract_features(training_data_query_log, dimensions)

# Standardize
original_scaled = pca_scaler.fit_transform(original_features)
diversified_scaled = pca_scaler.transform(diversified_features)

# Apply PCA to reduce to 2D
pca = PCA(n_components=2)
original_pca = pca.fit_transform(original_scaled)
diversified_pca = pca.transform(diversified_scaled)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Before diversification
axes[0].scatter(original_pca[:, 0], original_pca[:, 1], alpha=0.5)
axes[0].set_title('Query Distribution Before Diversification')
axes[0].set_xlabel('PCA Component 1')
axes[0].set_ylabel('PCA Component 2')

# After diversification
axes[1].scatter(diversified_pca[:, 0], diversified_pca[:, 1], alpha=0.5, color='orange')
axes[1].set_title('Query Distribution After Diversification')
axes[1].set_xlabel('PCA Component 1')
axes[1].set_ylabel('PCA Component 2')

plt.tight_layout()
plt.show()

# %% [markdown]
# Build testing data.

# %%
testing_data_query_log = generate_power_query_log(agg_col, 100, data, sample, dimensions, full_data_size, avg_exact=avg_exact)
# Out:
# Generating power query log...
# Generated 100 queries in 218 attempts

# %% [markdown]
# Check training, testing data size.

# %%
print("Training data: ", len(training_data_query_log), "\nTesting data: ",  len(testing_data_query_log))
# Out:
# Training data:  800
# Testing data:  100

# %% [markdown]
# ### Step 4: Train the Error Prediction Model

# %% [markdown]
# Load model if needed.

# %%
# import joblib

# model_data = joblib.load("regression_pipeline.pkl")
# model = model_data["model"]

# %% [markdown]
# Train model.

# %%
from sklearn.ensemble import RandomForestRegressor
error_scaler = StandardScaler()

def data_split(query_log, scaler=None, fit=False):
    # Prepare features (flatten lower, upper per dim) and targets (errors)
    X = []
    y = []
    for entry in query_log:

        vec = []
        for dim in dimensions:
            lower, upper = entry['query'][dim]
            vec.extend([lower, upper])
        X.append(vec)
        y.append(entry['error'])

    X = np.array(X)
    y = np.array(y)

    # Normalize
    if fit:
        X_scaled = scaler.fit_transform(X)
    else:
        X_scaled = scaler.transform(X)

    return X_scaled, y

X_train, y_train = data_split(training_data_query_log, error_scaler, fit=True)
X_test,  y_test  = data_split(testing_data_query_log,  error_scaler, fit=False)

model = RandomForestRegressor(
    # n_estimators=200,
    max_depth=3,
    min_samples_leaf=5,
    max_features="sqrt",
    random_state=42
)

model.fit(X_train, y_train)
print(f"Model trained.")

# Evaluate model using MSE
train_mse = np.mean((model.predict(X_train) - y_train) ** 2)
test_mse  = np.mean((model.predict(X_test)  - y_test)  ** 2)
print(f"Train MSE: {train_mse}")
print(f"Test  MSE: {test_mse}")
# Out:
# Model trained.
# Train MSE: 13185379.40968362
# Test  MSE: 14774122.78955467

# %% [markdown]
# ### Step 5: Estimate a New Query

# %%
new_query = generate_bounded_random_query(data, dimensions, test = True)
print(new_query)
# Out:
# dim: timestamp, min value: 0.0, max value: 124515480.0
# dim: Global_reactive_power, min value: 0.0, max value: 1.39
# dim: Voltage, min value: 223.2, max value: 254.15
# dim: Global_intensity, min value: 0.2, max value: 48.4
# dim: Sub_metering_1, min value: 0.0, max value: 88.0
# dim: Sub_metering_2, min value: 0.0, max value: 80.0
# dim: Sub_metering_3, min value: 0.0, max value: 31.0
# {'timestamp': (3577807.737770584, 96791804.7104849), 'Global_reactive_power': (0.271353897370855, 1.1814302115000588), 'Voltage': (223.34173750309313, 246.87943799532994), 'Global_intensity': (4.2215401113875055, 38.37287857247847), 'Sub_metering_1': (18.653718962961573, 82.1679872740097), 'Sub_metering_2': (4.168099101801525, 60.93766592084762), 'Sub_metering_3': (0.08925599342311794, 23.559539810691067)}

# %%
from query_calculate import sample_sum, exact_sum

# Flatten and scale
new_vec = []
for dim in dimensions:
    lower, upper = new_query[dim]
    new_vec.extend([lower, upper])
new_vec = np.array([new_vec])
new_scaled = error_scaler.transform(new_vec)

# Predict error
predicted_error = model.predict(new_scaled)[0]

# Find error-similar historical query (closest error)
min_diff = float('inf')
opt_entry = None
for entry in training_data_query_log:
    error_diff = abs(entry['error'] - predicted_error)
    if error_diff < min_diff:
        min_diff = error_diff
        opt_entry = entry

# final estimate
sample_new = sample_sum(agg_col, new_query, sample, full_data_size)
sample_opt = opt_entry['estimate']
final_estimate = opt_entry['exact'] + (sample_new - sample_opt)

print(f"LAQP estimate: {final_estimate:.2f}")
# Compute exact for the same query
exact = exact_sum(agg_col, new_query, data)
print(f"Exact sum: {exact:.2f}")
print(f"Relative error: {abs(final_estimate - exact) / exact:.4f}")
# Out:
# LAQP estimate: 4047.05
# Exact sum: 6671.42
# Relative error: 0.3934

# %% [markdown]
# ### Step 6: Evaluate and Extend

# %% [markdown]
# Optimization

# %%
from optimization import optimize_alpha, range_distance

best_alpha = optimize_alpha(training_data_query_log, testing_data_query_log, dimensions, error_scaler, model, sample, full_data_size, task)
# Out:
# Optimized alpha: 0.854 (MSE on val: 0.3419)

# %%
from estimation import optimized_laqp_estimate
from estimation import laqp_estimate

estimate, opt_idx, opt_entry = laqp_estimate(training_data_query_log, new_query, sample, dimensions, model, error_scaler, full_data_size, task)

# Optimized 
opt_est, opt_entry = optimized_laqp_estimate(training_data_query_log, new_query, sample, dimensions, model, error_scaler, full_data_size, task, best_alpha)

# Compare
exact = exact_sum(agg_col, new_query, data)
print(f"\nExact: {exact}")
print(f"Basic rel error: {abs(estimate - exact) / exact:.4f}")
print(f"Optimized rel error: {abs(opt_est - exact) / exact:.4f}")
# Out:
# Selected optimal query index: 636 (out of  800)
# Basic LAQP estimate: 4047.05
# Predicted error for new query: 4040.88
# Chosen historical query error: 4047.05 (diff: 6.17)
#
# Optimized LAQP estimate: 1518.74
# Predicted error for new query: 4040.88
# Chosen historical query error: 1518.74
#
# Exact: 6671.424
# Basic rel error: 0.3934
# Optimized rel error: 0.7724

# %% [markdown]
# Generate evaluation query log (100).

# %%
evaluation_query_log = generate_power_query_log(agg_col, 100, data, sample, dimensions, full_data_size, avg_exact=avg_exact)
# Out:
# Generating power query log...
# Generated 100 queries in 202 attempts

# %%
# Evaluation on evaluation_query_log 
laqp_rel_errors = []
sampling_rel_errors = []
laqp_squared_errors = []
sampling_squared_errors = []
laqp_abs_errors = []
sampling_abs_errors = []
aqp_pp_abs_errors = []
aqp_pp_rel_errors = []
aqp_pp_squared_errors = []

min_exact_threshold = 100 
filtered_count = 0

evaluation_query_log_num = 0

for tq in evaluation_query_log:
    evaluation_query_log_num += 1
    LAQP_select = 0
    AQPpp_select = 0

    query = tq['query']
    exact = tq['exact']
    
    if exact < min_exact_threshold:
        continue
    filtered_count += 1
    
    # Sampling Estimate
    sample_est = sample_sum(agg_col, query, sample, full_data_size)
    sampling_abs = abs(sample_est - exact)
    sampling_rel = sampling_abs / exact if exact > 0 else 0
    sampling_sq = (sample_est - exact)**2
    
    sampling_abs_errors.append(sampling_abs)
    sampling_rel_errors.append(sampling_rel)
    sampling_squared_errors.append(sampling_sq)

    # AQP++ Estimate
    min_dist = float('inf')
    aqp_pp_entry = None

    for i, entry in enumerate(training_data_query_log):
        dist = range_distance(dimensions, query, entry['query'])
        if dist < min_dist:
            min_dist = dist
            aqp_pp_entry = entry
            AQPpp_select = i

    q_old_exact = aqp_pp_entry['exact']
    q_hat_new = sample_sum(agg_col, query, sample, full_data_size)
    q_hat_old = aqp_pp_entry['estimate']
    aqp_pp_est = q_old_exact + (q_hat_new - q_hat_old)

    aqp_pp_abs = abs(aqp_pp_est - exact)
    aqp_pp_rel = aqp_pp_abs / exact if exact > 0 else 0
    aqp_pp_sq = (aqp_pp_est - exact)**2
    
    aqp_pp_abs_errors.append(aqp_pp_abs)
    aqp_pp_rel_errors.append(aqp_pp_rel)
    aqp_pp_squared_errors.append(aqp_pp_sq)

    # LAQP Estimate
    vec = [query[dim][i] for dim in dimensions for i in range(2)]
    vec = np.array([vec])
    scaled = error_scaler.transform(vec)
    pred_error = model.predict(scaled)[0]
    LAQP_select, best_entry = min(
        enumerate(training_data_query_log),
        key=lambda
        e: best_alpha * (e[1]['error'] - pred_error) ** 2 + 
        (1 - best_alpha) * range_distance(dimensions, query, e[1]['query'])
    )
    sample_new = sample_sum(agg_col, query, sample, full_data_size)
    sample_opt = best_entry['estimate']
    laqp_est = best_entry['exact'] + (sample_new - sample_opt)
    
    laqp_abs = abs(laqp_est - exact)
    laqp_rel = laqp_abs / exact if exact > 0 else 0
    laqp_sq = (laqp_est - exact)**2
    
    laqp_abs_errors.append(laqp_abs)
    laqp_rel_errors.append(laqp_rel)
    laqp_squared_errors.append(laqp_sq)

    print("evaluation_query_log_num:", evaluation_query_log_num)
    print("LAQP_select: ", LAQP_select)
    print("AQP++_select: ", AQPpp_select)

# Results
print(f"Evaluated on {filtered_count} / {len(evaluation_query_log)} queries "
      f"(excluded {len(evaluation_query_log)-filtered_count} tiny ones)")

if len(laqp_rel_errors) > 0:
    laqp_are = np.mean(laqp_rel_errors)
    sampling_are = np.mean(sampling_rel_errors)
    aqp_pp_are = np.mean(aqp_pp_rel_errors)
    laqp_mse = np.mean(laqp_squared_errors)
    sampling_mse = np.mean(sampling_squared_errors)
    aqp_pp_mse = np.mean(aqp_pp_squared_errors)
    laqp_mae = np.mean(laqp_abs_errors)
    sampling_mae = np.mean(sampling_abs_errors)
    aqp_pp_mae = np.mean(aqp_pp_abs_errors)

    print(f"\nLAQP    Average Relative Error (ARE): {laqp_are:.4f}")
    print(f"LAQP    Median Relative Error:       {np.median(laqp_rel_errors):.4f}")
    print(f"LAQP    Mean Squared Error (MSE):    {laqp_mse:.2f}")
    print(f"LAQP    Mean Absolute Error (MAE):   {laqp_mae:.2f}")
    
    print(f"\nSampling ARE:                       {sampling_are:.4f}")
    print(f"Sampling Median Relative Error:     {np.median(sampling_rel_errors):.4f}")
    print(f"Sampling MSE:                       {sampling_mse:.2f}")
    print(f"Sampling MAE:                       {sampling_mae:.2f}")
    
    print(f"\nAQP++ ARE:                       {aqp_pp_are:.4f}")
    print(f"AQP++ Median Relative Error:     {np.median(aqp_pp_rel_errors):.4f}")
    print(f"AQP++ MSE:                       {aqp_pp_mse:.2f}")
    print(f"AQP++ MAE:                       {aqp_pp_mae:.2f}")
    
    sampling_improvement = sampling_are / laqp_are if laqp_are > 0 else 0
    print(f"\nImprovement (Sampling ARE / LAQP ARE): {sampling_improvement:.2f}x")
    aqp_pp_improvement = aqp_pp_are / laqp_are if laqp_are > 0 else 0
    print(f"\nImprovement (AQP++ ARE / LAQP ARE): {aqp_pp_improvement:.2f}x")
else:
    print("No queries passed the threshold — lower min_exact_threshold")
# Out:
# evaluation_query_log_num: 1
# LAQP_select:  194
# AQP++_select:  194
# evaluation_query_log_num: 2
# LAQP_select:  265
# AQP++_select:  265
# evaluation_query_log_num: 3
# LAQP_select:  547
# AQP++_select:  547
# evaluation_query_log_num: 4
# LAQP_select:  109
# AQP++_select:  109
# evaluation_query_log_num: 5
# LAQP_select:  792
# AQP++_select:  792
# evaluation_query_log_num: 6
# LAQP_select:  701
# AQP++_select:  701
# evaluation_query_log_num: 7
# LAQP_select:  198
# AQP++_select:  198
# evaluation_query_log_num: 8
# LAQP_select:  87
# AQP++_select:  87
# evaluation_query_log_num: 9
# LAQP_select:  175
# AQP++_select:  175
# evaluation_query_log_num: 10
# LAQP_select:  589
# AQP++_select:  589
# evaluation_query_log_num: 11
# LAQP_select:  303
# AQP++_select:  303
# evaluation_query_log_num: 12
# LAQP_select:  13
# AQP++_select:  13
# evaluation_query_log_num: 13
# LAQP_select:  706
# AQP++_select:  706
# evaluation_query_log_num: 14
# LAQP_select:  634
# AQP++_select:  634
# evaluation_query_log_num: 15
# LAQP_select:  756
# AQP++_select:  756
# evaluation_query_log_num: 16
# LAQP_select:  269
# AQP++_select:  269
# evaluation_query_log_num: 17
# LAQP_select:  240
# AQP++_select:  240
# evaluation_query_log_num: 18
# LAQP_select:  515
# AQP++_select:  515
# evaluation_query_log_num: 19
# LAQP_select:  358
# AQP++_select:  358
# evaluation_query_log_num: 20
# LAQP_select:  700
# AQP++_select:  700
# evaluation_query_log_num: 21
# LAQP_select:  586
# AQP++_select:  586
# evaluation_query_log_num: 22
# LAQP_select:  233
# AQP++_select:  233
# evaluation_query_log_num: 23
# LAQP_select:  131
# AQP++_select:  131
# evaluation_query_log_num: 24
# LAQP_select:  714
# AQP++_select:  714
# evaluation_query_log_num: 25
# LAQP_select:  669
# AQP++_select:  669
# evaluation_query_log_num: 26
# LAQP_select:  322
# AQP++_select:  322
# evaluation_query_log_num: 27
# LAQP_select:  505
# AQP++_select:  505
# evaluation_query_log_num: 28
# LAQP_select:  589
# AQP++_select:  589
# evaluation_query_log_num: 29
# LAQP_select:  696
# AQP++_select:  696
# evaluation_query_log_num: 30
# LAQP_select:  532
# AQP++_select:  532
# evaluation_query_log_num: 31
# LAQP_select:  132
# AQP++_select:  132
# evaluation_query_log_num: 32
# LAQP_select:  468
# AQP++_select:  468
# evaluation_query_log_num: 33
# LAQP_select:  544
# AQP++_select:  544
# evaluation_query_log_num: 34
# LAQP_select:  204
# AQP++_select:  204
# evaluation_query_log_num: 35
# LAQP_select:  335
# AQP++_select:  335
# evaluation_query_log_num: 36
# LAQP_select:  459
# AQP++_select:  459
# evaluation_query_log_num: 37
# LAQP_select:  230
# AQP++_select:  230
# evaluation_query_log_num: 38
# LAQP_select:  4
# AQP++_select:  4
# evaluation_query_log_num: 39
# LAQP_select:  107
# AQP++_select:  107
# evaluation_query_log_num: 40
# LAQP_select:  400
# AQP++_select:  400
# evaluation_query_log_num: 41
# LAQP_select:  460
# AQP++_select:  460
# evaluation_query_log_num: 42
# LAQP_select:  102
# AQP++_select:  102
# evaluation_query_log_num: 43
# LAQP_select:  69
# AQP++_select:  69
# evaluation_query_log_num: 44
# LAQP_select:  342
# AQP++_select:  342
# evaluation_query_log_num: 45
# LAQP_select:  171
# AQP++_select:  171
# evaluation_query_log_num: 46
# LAQP_select:  623
# AQP++_select:  623
# evaluation_query_log_num: 47
# LAQP_select:  158
# AQP++_select:  158
# evaluation_query_log_num: 48
# LAQP_select:  182
# AQP++_select:  182
# evaluation_query_log_num: 49
# LAQP_select:  219
# AQP++_select:  219
# evaluation_query_log_num: 50
# LAQP_select:  407
# AQP++_select:  407
# evaluation_query_log_num: 51
# LAQP_select:  462
# AQP++_select:  462
# evaluation_query_log_num: 52
# LAQP_select:  253
# AQP++_select:  253
# evaluation_query_log_num: 53
# LAQP_select:  537
# AQP++_select:  537
# evaluation_query_log_num: 54
# LAQP_select:  445
# AQP++_select:  445
# evaluation_query_log_num: 55
# LAQP_select:  699
# AQP++_select:  699
# evaluation_query_log_num: 56
# LAQP_select:  260
# AQP++_select:  260
# evaluation_query_log_num: 57
# LAQP_select:  368
# AQP++_select:  368
# evaluation_query_log_num: 58
# LAQP_select:  224
# AQP++_select:  224
# evaluation_query_log_num: 59
# LAQP_select:  104
# AQP++_select:  104
# evaluation_query_log_num: 60
# LAQP_select:  604
# AQP++_select:  604
# evaluation_query_log_num: 61
# LAQP_select:  172
# AQP++_select:  172
# evaluation_query_log_num: 62
# LAQP_select:  136
# AQP++_select:  136
# evaluation_query_log_num: 63
# LAQP_select:  776
# AQP++_select:  776
# evaluation_query_log_num: 64
# LAQP_select:  276
# AQP++_select:  276
# evaluation_query_log_num: 65
# LAQP_select:  362
# AQP++_select:  362
# evaluation_query_log_num: 66
# LAQP_select:  686
# AQP++_select:  686
# evaluation_query_log_num: 67
# LAQP_select:  169
# AQP++_select:  169
# evaluation_query_log_num: 68
# LAQP_select:  29
# AQP++_select:  29
# evaluation_query_log_num: 69
# LAQP_select:  428
# AQP++_select:  428
# evaluation_query_log_num: 70
# LAQP_select:  482
# AQP++_select:  482
# evaluation_query_log_num: 71
# LAQP_select:  250
# AQP++_select:  250
# evaluation_query_log_num: 72
# LAQP_select:  551
# AQP++_select:  551
# evaluation_query_log_num: 73
# LAQP_select:  609
# AQP++_select:  609
# evaluation_query_log_num: 74
# LAQP_select:  583
# AQP++_select:  583
# evaluation_query_log_num: 75
# LAQP_select:  476
# AQP++_select:  476
# evaluation_query_log_num: 76
# LAQP_select:  429
# AQP++_select:  429
# evaluation_query_log_num: 77
# LAQP_select:  680
# AQP++_select:  680
# evaluation_query_log_num: 78
# LAQP_select:  353
# AQP++_select:  353
# evaluation_query_log_num: 79
# LAQP_select:  123
# AQP++_select:  123
# evaluation_query_log_num: 80
# LAQP_select:  202
# AQP++_select:  202
# evaluation_query_log_num: 81
# LAQP_select:  172
# AQP++_select:  172
# evaluation_query_log_num: 82
# LAQP_select:  421
# AQP++_select:  421
# evaluation_query_log_num: 83
# LAQP_select:  600
# AQP++_select:  600
# evaluation_query_log_num: 84
# LAQP_select:  197
# AQP++_select:  197
# evaluation_query_log_num: 85
# LAQP_select:  37
# AQP++_select:  37
# evaluation_query_log_num: 86
# LAQP_select:  624
# AQP++_select:  624
# evaluation_query_log_num: 87
# LAQP_select:  147
# AQP++_select:  147
# evaluation_query_log_num: 88
# LAQP_select:  129
# AQP++_select:  129
# evaluation_query_log_num: 89
# LAQP_select:  770
# AQP++_select:  770
# evaluation_query_log_num: 90
# LAQP_select:  142
# AQP++_select:  142
# evaluation_query_log_num: 91
# LAQP_select:  708
# AQP++_select:  708
# evaluation_query_log_num: 92
# LAQP_select:  719
# AQP++_select:  719
# evaluation_query_log_num: 93
# LAQP_select:  547
# AQP++_select:  547
# evaluation_query_log_num: 94
# LAQP_select:  510
# AQP++_select:  510
# evaluation_query_log_num: 95
# LAQP_select:  750
# AQP++_select:  750
# evaluation_query_log_num: 96
# LAQP_select:  308
# AQP++_select:  308
# evaluation_query_log_num: 97
# LAQP_select:  390
# AQP++_select:  390
# evaluation_query_log_num: 98
# LAQP_select:  308
# AQP++_select:  308
# evaluation_query_log_num: 99
# LAQP_select:  670
# AQP++_select:  670
# evaluation_query_log_num: 100
# LAQP_select:  397
# AQP++_select:  397
# Evaluated on 100 / 100 queries (excluded 0 tiny ones)
#
# LAQP    Average Relative Error (ARE): 0.4077
# LAQP    Median Relative Error:       0.3099
# LAQP    Mean Squared Error (MSE):    47280095.63
# LAQP    Mean Absolute Error (MAE):   4959.00
#
# Sampling ARE:                       0.4117
# Sampling Median Relative Error:     0.4349
# Sampling MSE:                       37997465.38
# Sampling MAE:                       5223.80
#
# AQP++ ARE:                       0.4077
# AQP++ Median Relative Error:     0.3099
# AQP++ MSE:                       47280095.63
# AQP++ MAE:                       4959.00
#
# Improvement (Sampling ARE / LAQP ARE): 1.01x
#
# Improvement (AQP++ ARE / LAQP ARE): 1.00x

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = ['LAQP', 'AQP++', 'Sampling']
are_values = [laqp_are, aqp_pp_are, sampling_are]
mse_values = [laqp_mse, aqp_pp_mse, sampling_mse]

x = np.arange(len(methods))
width = 0.25

# chart for ARE
fig, ax1 = plt.subplots(figsize=(9, 5))
ax1.bar(x - width, are_values[0], width, label='LAQP', color='#1f77b4')
ax1.bar(x,   are_values[1], width, label='AQP++', color='#2ca02c')
ax1.bar(x + width, are_values[2], width, label='Sampling', color='#ff7f0e')

ax1.set_ylabel('Average Relative Error (ARE)')
ax1.set_title('Comparison of ARE among LAQP, Sampling and AQP++')
ax1.set_xticks(x)
ax1.set_xticklabels(methods)
ax1.legend(loc='upper left')
ax1.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# chart for MSE
fig, ax2 = plt.subplots(figsize=(9, 5))
ax2.bar(x - width, mse_values[0], width, label='LAQP', color='#1f77b4')
ax2.bar(x, mse_values[1], width, label='AQP++', color='#2ca02c')
ax2.bar(x + width, mse_values[2], width, label='Sampling', color='#ff7f0e')

ax2.set_ylabel('Mean Squared Error (MSE)')
ax2.set_title('Comparison of MSE among LAQP, Sampling and AQP++')
ax2.set_xticks(x)
ax2.set_xticklabels(methods)
ax2.legend(loc='upper left')
ax2.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Save if needed.

# %%
import joblib

joblib.dump({
    "model": model,
    "error_scaler": error_scaler,
    "training_query": training_data_query_log,
    "testing_query" : testing_data_query_log,
    "alpha": best_alpha,
    "sample": sample
}, "./weights/12_29_power.pkl")
# Out:
# ['./weights/12_29_power.pkl']
